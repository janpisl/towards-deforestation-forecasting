# %%
import pandas as pd

# %%
train = pd.read_csv('../data/tmp/train.csv')
val = pd.read_csv('../data/tmp/val.csv')
test = pd.read_csv('../data/original_annotation/15k_test.csv')

# %%
test['split'] = 'test'

# %%
df = pd.concat([train,val,test]).reset_index(drop=True)

# %%
df = df.drop(['n_pixels_1987', 'n_pixels_1988',
       'n_pixels_1989', 'n_pixels_1990', 'n_pixels_1991', 'n_pixels_1992',
       'n_pixels_1993', 'n_pixels_1994', 'n_pixels_1995', 'n_pixels_1996',
       'n_pixels_1997', 'n_pixels_1998', 'n_pixels_1999', 'n_pixels_2000',
       'n_pixels_2001', 'n_pixels_2002', 'n_pixels_2003', 'n_pixels_2004',
       'n_pixels_2005', 'n_pixels_2006', 'n_pixels_2007', 'n_pixels_2008',
       'n_pixels_2009', 'n_pixels_2021', 'valid_start_years', 'input_patch_row', 'input_patch_col', 'test_split'], axis=1)

# %%
df.split.value_counts()
# Out:
# split
# train    124247
# test      15000
# val        8752
# Name: count, dtype: int64

# %%
cell
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 cell
#
# NameError: name 'cell' is not defined

# %%
df.to_csv("../data/original_annotation/annotation.csv", index=False)

# %%
test = pd.read_csv('../data/original_annotation/15k_test.csv')

# %%
test.split
# Out:
# 0        val
# 1        val
# 2        val
# 3        val
# 4        val
#         ...
# 14995    val
# 14996    val
# 14997    val
# 14998    val
# 14999    val
# Name: split, Length: 15000, dtype: object
